# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
import warnings
warnings.filterwarnings("ignore")
iris = pd.read_csv('iris.csv')
wh=pd.read_csv('weatherHistory.csv')
iris.head(10)
wh.head(10)

# %%
df = pd.DataFrame(iris)
df1 = pd.DataFrame(wh)

# %%
categorical_counts = df['variety'].value_counts()
categorical_counts = df1['Summary'].value_counts()
categorical_counts = df1['Daily Summary'].value_counts()

# %%
mean_value1 = df['sepal.width'].mean()
median_value1 = df['sepal.width'].median()
std_value1 = df['sepal.width'].std()

# %%
print("Number of samples in each categorical value:")
print(categorical_counts)
print("\nMean Value:", mean_value1)
print("Median Value:", median_value1)
print("Standard Deviation:", std_value1)
# Out:
# Number of samples in each categorical value:
# Setosa        50
# Versicolor    50
# Virginica     50
# Name: variety, dtype: int64
#
# Mean Value: 3.0573333333333337
# Median Value: 3.0
# Standard Deviation: 0.4358662849366982

# %%
mean_value = df['sepal.length'].mean()
median_value = df['sepal.length'].median()
std_value = df['sepal.length'].std()

# %%
print("Number of samples in each categorical value:")
print(categorical_counts)
print("\nMean Value:", mean_value)
print("Median Value:", median_value)
print("Standard Deviation:", std_value)
# Out:
# Number of samples in each categorical value:
# Setosa        50
# Versicolor    50
# Virginica     50
# Name: variety, dtype: int64
#
# Mean Value: 5.843333333333334
# Median Value: 5.8
# Standard Deviation: 0.828066127977863

# %%
mean_value = df['petal.length'].mean()
median_value = df['petal.length'].median()
std_value = df['petal.length'].std()

# %%
print("Number of samples in each categorical value:")
print(categorical_counts)
print("\nMean Value:", mean_value)
print("Median Value:", median_value)
print("Standard Deviation:", std_value)
# Out:
# Number of samples in each categorical value:
# Setosa        50
# Versicolor    50
# Virginica     50
# Name: variety, dtype: int64
#
# Mean Value: 3.7580000000000005
# Median Value: 4.35
# Standard Deviation: 1.7652982332594662

# %%
mean_value = df['petal.width'].mean()
median_value = df['petal.width'].median()
std_value = df['petal.width'].std()

# %%
print("Number of samples in each categorical value:")
print(categorical_counts)
print("\nMean Value:", mean_value)
print("Median Value:", median_value)
print("Standard Deviation:", std_value)
# Out:
# Number of samples in each categorical value:
# Setosa        50
# Versicolor    50
# Virginica     50
# Name: variety, dtype: int64
#
# Mean Value: 1.1993333333333336
# Median Value: 1.3
# Standard Deviation: 0.7622376689603465

# %%
mean_value = df1['Humidity'].mean()
median_value = df1['Humidity'].median()
std_value = df1['Humidity'].std()

# %%
print("Number of samples in each categorical value:")
print(categorical_counts)
print("\nMean Value:", mean_value)
print("Median Value:", median_value)
print("Standard Deviation:", std_value)
# Out:
# Number of samples in each categorical value:
# Mostly cloudy throughout the day.                                                                       20085
# Partly cloudy throughout the day.                                                                        9981
# Partly cloudy until night.                                                                               6169
# Partly cloudy starting in the morning.                                                                   5184
# Foggy in the morning.                                                                                    4201
#                                                                                                         ...
# Breezy starting overnight continuing until morning and foggy overnight.                                    24
# Mostly cloudy throughout the day and breezy starting overnight continuing until afternoon.                 24
# ...
